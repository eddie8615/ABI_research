# %%
import pandas as pd
import os

# %%
data_path = os.path.relpath('./Data')

# %%
df_train = pd.read_csv(os.path.join(data_path, 'train.csv'))
df_validation = pd.read_csv(os.path.join(data_path, 'validation.csv'))
df_test = pd.read_csv(os.path.join(data_path, 'test.csv'))

df = pd.concat([df_train,df_validation,df_test], axis=0)
df
# Out:
#                     podcast            start                        end  \
# 0     MSP-PODCAST_0227_0263  0 days 00:00:00     0 days 00:00:10.049000
# 1     MSP-PODCAST_0135_0064  0 days 00:00:00  0 days 00:00:02.570812500
# 2     MSP-PODCAST_0166_0631  0 days 00:00:00     0 days 00:00:06.403250
# 3     MSP-PODCAST_0035_0089  0 days 00:00:00     0 days 00:00:04.120000
# 4     MSP-PODCAST_1170_0024  0 days 00:00:00     0 days 00:00:05.470000
# ...                     ...              ...                        ...
# 1498  MSP-PODCAST_0114_0172  0 days 00:00:00  0 days 00:00:05.346187500
# 1499  MSP-PODCAST_0381_0417  0 days 00:00:00     0 days 00:00:03.060000
# 1500  MSP-PODCAST_0281_0098  0 days 00:00:00  0 days 00:00:03.167312500
# 1501  MSP-PODCAST_0167_0171  0 days 00:00:00     0 days 00:00:10.680000
# 1502  MSP-PODCAST_0114_0251  0 days 00:00:00  0 days 00:00:03.359687500
#
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                             29.599983
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
df = df.drop(columns=['podcast', 'start', 'end'])

# %%
df.shape
# Out:
# (4954, 91)

# %%
features = df_train.columns[0:88]
targets = df_train.columns[88:]

# %%
x = df.loc[:, features]

# %%
std_x = StandardScaler().fit_transform(x)
std_x.shape
# Out:
# (4954, 88)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=50)
principalComponents = pca.fit_transform(std_x)
principalDf = pd.DataFrame(data = principalComponents)

# %%
principalDf
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.605555  2.387002 -3.929734 -2.478130  0.799650 -2.443066  1.326119
# 1    -7.998278  1.304372 -1.101990  0.172987  0.758387  1.406812 -0.865455
# 2     0.063687 -1.521912 -1.249056  0.866106 -0.359806  0.798749  0.761522
# 3    -6.742737  0.429290 -0.115333 -3.523155 -0.425287  0.741611  1.797805
# 4    -2.756763 -2.494494  0.946973 -1.013630 -0.234690 -1.892978 -0.458910
# ...        ...       ...       ...       ...       ...       ...       ...
# 4949  4.006623  3.436525 -6.186134  0.927278 -2.249757 -1.568711 -0.144547
# 4950 -3.939283  2.534803 -1.087368 -2.164002  1.038841  1.157197 -1.444933
# 4951  7.197335 -3.736672  7.883249  0.044451  2.530457 -1.222219  1.109883
# 4952  3.551629  2.192907 -0.166543  0.314895  0.028098 -2.083979 -0.183620
# 4953  2.800188  4.736181 -5.881631  0.546051 -1.275986 -2.865342 -0.494557
#
# ...

# %%
pca.explained_variance_ratio_
# Out:
# array([0.1787864 , 0.08927301, 0.08583959, 0.06189865, 0.04716351,
#        0.0408999 , 0.0319276 , 0.02851536, 0.02287988, 0.02130257,
#        0.01979403, 0.01825128, 0.01599809, 0.01572891, 0.014668  ,
#        0.0123562 , 0.01167974, 0.0115734 , 0.01147323, 0.01143548,
#        0.01140663, 0.0113472 , 0.01132098, 0.01126481, 0.01123982,
#        0.01118578, 0.0108111 , 0.01063674, 0.01022446, 0.00982685,
#        0.00897743, 0.00840972, 0.00794181, 0.00768178, 0.00737004,
#        0.0064113 , 0.00579502, 0.00540244, 0.00516535, 0.00476183,
#        0.00441214, 0.00427372, 0.00389975, 0.00384734, 0.00368479,
#        0.00364429, 0.00331062, 0.00317765, 0.00301816, 0.00283779])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9647321841825169

# %%
df
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                             29.599983
# 1                             16.518946
# 2                             31.418877
# 3                             24.457880
# 4                             32.391113
# ...                                 ...
# 1498                          32.482777
# 1499                          23.509320
# 1500                          43.610775
# 1501                          33.705900
# 1502                          29.654655
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.136860
# 1                                   0.082243
# 2                                   0.141456
# 3                                   0.214500
# 4                                   0.090431
# ...                                      ...
# 1498                                0.128275
# 1499                                0.168099
# 1500                                0.174068
# ...

# %%
outcomes = df.loc[:, targets]
outcomes.describe()
# Out:
#            arousal      valence    dominance
# count  4954.000000  4954.000000  4954.000000
# mean     23.037082     6.753560    25.078226
# std      12.444118    18.556616    10.227981
# min     -22.787696   -64.123661   -11.331838
# 25%      15.388783    -6.612730    18.956931
# 50%      22.945282     8.676715    25.308288
# 75%      30.373901    20.865426    31.400356
# max      78.299490    60.128094    65.053079
